# %%
import os
import streamlit as st
import pickle
import time
import requests
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.qa_with_sources.loading import load_qa_with_sources_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings  # Substitute with alternative embeddings
from langchain.vectorstores import FAISS

# %%
pip install -U langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\hp\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from langchain-huggingface) (0.26.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\hp\anaconda3\lib\site-packages (from langchain-huggingface) (0.3.15)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from langchain-huggingface) (3.2.1)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from langchain-huggingface) (0.20.3)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from langchain-huggingface) (4.46.2)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.29.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.1.140)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (8.2.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.2.2)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.10.1)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (10.3.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2022.7.9)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hp\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.4.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2023.7.22)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain-huggingface) (0.4.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (2.2.0)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\hp\anaconda3\lib\site-packages (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (0.6.10)
# Requirement already satisfied: google-api-core in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-generativeai) (2.22.0)
# Requirement already satisfied: google-api-python-client in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (2.151.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (2.36.0)
# Requirement already satisfied: protobuf in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (5.28.3)
# Requirement already satisfied: pydantic in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (2.9.2)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (4.67.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.7.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.29.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hp\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.23.4)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python311\site-packages (from tqdm->google-generativeai) (0.4.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.67.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\hp\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (4.65.0)Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.5 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Collecting tqdm
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
#                                               0.0/78.6 kB ? eta -:--:--
#      ---------------                          30.7/78.6 kB ? eta -:--:--
#      ---------------                          30.7/78.6 kB ? eta -:--:--
#      ---------------                          30.7/78.6 kB ? eta -:--:--
#      ---------------                          30.7/78.6 kB ? eta -:--:--
#      -------------------------------------- 78.6/78.6 kB 312.1 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python311\site-packages (from tqdm) (0.4.4)
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
# Successfully installed tqdm-4.67.0

# %%
pip install Runnable
# Out:
# Collecting Runnable
#   Downloading runnable-0.13.0-py3-none-any.whl (122 kB)
#                                               0.0/122.7 kB ? eta -:--:--
#      ----------                               30.7/122.7 kB ? eta -:--:--
#      ----------                               30.7/122.7 kB ? eta -:--:--
#      ----------                               30.7/122.7 kB ? eta -:--:--
#      ----------                               30.7/122.7 kB ? eta -:--:--
#      ------------                          41.0/122.7 kB 164.3 kB/s eta 0:00:01
#      ------------                          41.0/122.7 kB 164.3 kB/s eta 0:00:01
#      ------------                          41.0/122.7 kB 164.3 kB/s eta 0:00:01
#      ---------------------                 71.7/122.7 kB 218.6 kB/s eta 0:00:01
#      ---------------------                 71.7/122.7 kB 218.6 kB/s eta 0:00:01
#      ---------------------------------    112.6/122.7 kB 262.6 kB/s eta 0:00:01
#      ------------------------------------ 122.7/122.7 kB 277.0 kB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from Runnable) (8.0.4)
# Collecting click-plugins<2.0.0,>=1.1.1 (from Runnable)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting dill<0.4.0,>=0.3.8 (from Runnable)
#   Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#                                               0.0/119.4 kB ? eta -:--:--
#      -------------------------------------- 119.4/119.4 kB 6.8 MB/s eta 0:00:00
# Collecting mlflow-skinny (from Runnable)
#   Downloading mlflow_skinny-2.17.2-py3-none-any.whl (5.7 MB)
#                                               0.0/5.7 MB ? eta -:--:--
#                                               0.1/5.7 MB ? eta -:--:--
#                                               0.1/5.7 MB ? eta -:--:--
#                                               0.1/5.7 MB ? eta -:--:--
#                                               0.1/5.7 MB ? eta -:--:--
#      -                                        0.1/5.7 MB 655.8 kB/s eta 0:00:09
#      -                                        0.2/5.7 MB 787.7 kB/s eta 0:00:07
#      -                                        0.3/5.7 MB 947.5 kB/s eta 0:00:06
#      --                                       0.4/5.7 MB 1.1 MB/s eta 0:00:05
#      --                                       0.4/5.7 MB 1.1 MB/s eta 0:00:05
#      --                                       0.4/5.7 MB 1.1 MB/s eta 0:00:05
#      --                                       0.4/5.7 MB 1.1 MB/s eta 0:00:05
#      ---                                      0.6/5.7 MB 1.1 MB/s eta 0:00:05
#      ---                                      0.6/5.7 MB 1.1 MB/s eta 0:00:05
#      ---                                      0.6/5.7 MB 1.1 MB/s eta 0:00:05
#      ---                                      0.6/5.7 MB 1.1 MB/s eta 0:00:05
#      ---                                      0.6/5.7 MB 1.1 MB/s eta 0:00:05
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ----                                     0.7/5.7 MB 961.4 kB/s eta 0:00:06
#      ------                                   0.9/5.7 MB 857.5 kB/s eta 0:00:06
#      ------                                   0.9/5.7 MB 857.5 kB/s eta 0:00:06
kB/s eta 0:00:01
#      ---------------------------------------  5.6/5.7 MB 825.6 kB/s eta 0:00:01
#      ---------------------------------------  5.6/5.7 MB 826.8 kB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 824.5 kB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 818.1 kB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from Runnable) (2.9.2)
# Requirement already satisfied: rich<14.0.0,>=13.5.2 in c:\users\hp\anaconda3\lib\site-packages (from Runnable) (13.7.1)
# Requirement already satisfied: ruamel.yaml in c:\users\hp\anaconda3\lib\site-packages (from Runnable) (0.17.21)
# Collecting ruamel.yaml.clib (from Runnable)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-win_amd64.whl (118 kB)
#                                               0.0/118.2 kB ? eta -:--:--
#      --------------------                    61.4/118.2 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 118.2/118.2 kB 1.1 MB/s eta 0:00:00
# Collecting stevedore<4.0.0,>=3.5.0 (from Runnable)
#   Downloading stevedore-3.5.2-py3-none-any.whl (50 kB)
#                                               0.0/50.2 kB ? eta -:--:--
#      ---------------------------------------- 50.2/50.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python311\site-packages (from click->Runnable) (0.4.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3.0,>=2.5->Runnable) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3.0,>=2.5->Runnable) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3.0,>=2.5->Runnable) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich<14.0.0,>=13.5.2->Runnable) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich<14.0.0,>=13.5.2->Runnable) (2.15.1)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore<4.0.0,>=3.5.0->Runnable)
#   Downloading pbr-6.1.0-py2.py3-none-any.whl (108 kB)
#                                               0.0/108.5 kB ? eta -:--:--
#      -----------                              30.7/108.5 kB ? eta -:--:--
#      -----------------------------           81.9/108.5 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 108.5/108.5 kB 893.5 kB/s eta 0:00:00
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (5.5.0)
# Requirement already satisfied: cloudpickle<4 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (2.2.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny->Runnable)
#   Downloading databricks_sdk-0.36.0-py3-none-any.whl (569 kB)
#                                               0.0/569.1 kB ? eta -:--:--
#      --                                    41.0/569.1 kB 960.0 kB/s eta 0:00:01
#      -----                                 92.2/569.1 kB 871.5 kB/s eta 0:00:01
#      ---------                            143.4/569.1 kB 944.1 kB/s eta 0:00:01
#      -----------                          174.1/569.1 kB 807.1 kB/s eta 0:00:01
#      ------------                         204.8/569.1 kB 778.2 kB/s eta 0:00:01
#      ---------------                      245.8/569.1 kB 835.2 kB/s eta 0:00:01
#      -----------------                    276.5/569.1 kB 811.7 kB/s eta 0:00:01
#      --------------------                 327.7/569.1 kB 846.5 kB/s eta 0:00:01
#      ----------------------               358.4/569.1 kB 825.0 kB/s eta 0:00:01
#      -----------------------              368.6/569.1 kB 791.2 kB/s eta 0:00:01
#      --------------------------           419.8/569.1 kB 819.2 kB/s eta 0:00:01
#      --------------------------           419.8/569.1 kB 819.2 kB/s eta 0:00:01
#      --------------------------           419.8/569.1 kB 819.2 kB/s eta 0:00:01
#      -------------------------------      491.5/569.1 kB 789.0 kB/s eta 0:00:01
#      ---------------------------------    522.2/569.1 kB 761.9 kB/s eta 0:00:01
#      ---------------------------------    532.5/569.1 kB 742.9 kB/s eta 0:00:01
#      ----------------------------------   553.0/569.1 kB 723.6 kB/s eta 0:00:01
#      ------------------------------------ 569.1/569.1 kB 701.2 kB/s eta 0:00:00
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\hp\appdata\roaming\python\python311\site-packages (from mlflow-skinny->Runnable) (3.1.43)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (6.0.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny->Runnable)
#   Downloading opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
#                                               0.0/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      ------                                   10.2/64.3 kB ? eta -:--:--
#      -------------------------------------- 64.3/64.3 kB 138.7 kB/s eta 0:00:00
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny->Runnable)
#   Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
#                                               0.0/118.7 kB ? eta -:--:--
#      ---                                      10.2/118.7 kB ? eta -:--:--
#      ------------                          41.0/118.7 kB 653.6 kB/s eta 0:00:01
#      -------------------                   61.4/118.7 kB 656.4 kB/s eta 0:00:01
#      ----------------------------          92.2/118.7 kB 581.0 kB/s eta 0:00:01
#      ------------------------------------ 118.7/118.7 kB 577.1 kB/s eta 0:00:00
# Requirement already satisfied: packaging<25 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (24.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (5.28.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\hp\anaconda3\lib\site-packages (from mlflow-skinny->Runnable) (2.29.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny->Runnable)
#   Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#                                               0.0/44.2 kB ? eta -:--:--
#      --------------------------             30.7/44.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 44.2/44.2 kB 547.0 kB/s eta 0:00:00
# Requirement already satisfied: google-auth~=2.0 in c:\users\hp\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny->Runnable) (2.36.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny->Runnable) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny->Runnable) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.2->Runnable) (0.1.0)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny->Runnable)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny->Runnable)
#   Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
#                                               0.0/159.2 kB ? eta -:--:--
#      ----------------------------             112.6/159.2 kB ? eta -:--:--
#      ----------------------------             112.6/159.2 kB ? eta -:--:--
#      ----------------------------             112.6/159.2 kB ? eta -:--:--
#      ----------------------------             112.6/159.2 kB ? eta -:--:--
#      ---------------------------          122.9/159.2 kB 654.9 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      --------------------------------     143.4/159.2 kB 652.5 kB/s eta 0:00:01
#      ----------------------------------   153.6/159.2 kB 305.7 kB/s eta 0:00:01
#      ------------------------------------ 159.2/159.2 kB 297.9 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny->Runnable) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny->Runnable) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny->Runnable) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\roaming\python\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny->Runnable) (2023.7.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\hp\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny->Runnable) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hp\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny->Runnable) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->Runnable) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\appdata\roaming\python\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->Runnable) (4.7.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->Runnable) (0.4.8)
# Installing collected packages: sqlparse, ruamel.yaml.clib, pbr, dill, deprecated, stevedore, opentelemetry-api, click-plugins, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-skinny, Runnable
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
# Successfully installed Runnable-0.13.0 click-plugins-1.1.1 databricks-sdk-0.36.0 deprecated-1.2.14 dill-0.3.9 mlflow-skinny-2.17.2 opentelemetry-api-1.28.1 opentelemetry-sdk-1.28.1 opentelemetry-semantic-conventions-0.49b1 pbr-6.1.0 ruamel.yaml.clib-0.2.12 sqlparse-0.5.1 stevedore-3.5.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylint 2.16.2 requires colorama>=0.4.5; sys_platform == "win32", but you have colorama 0.4.4 which is incompatible.
# spyder 5.4.3 requires keyring>=17.0.0, but you have keyring 8.7 which is incompatible.

# %%
# Set up the API key for Vertex AI
api_key = "api-key"
location = "us-central1"  # or the region where your Vertex AI is deployed
model_id = "gemini"  # Use the model ID associated with Gemini on Vertex AI

# %%
# Vertex AI endpoint for predictions
endpoint = f"https://{location}-aiplatform.googleapis.com/v1/projects/YOUR_PROJECT_ID/locations/{location}/publishers/google/models/{model_id}:predict"

# %%
# Load and process documents
loaders = UnstructuredURLLoader(urls=[
    "https://www.moneycontrol.com/news/business/markets/wall-street-rises-as-tesla-soars-on-ai-optimism-11351111.html",
    "https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html"
])
data = loaders.load()

# %%
len(data)
# Out:
# 2

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
docs = text_splitter.split_documents(data)

# %%
from tqdm import tqdm, trange

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

vectorindex_vertex = FAISS.from_documents(docs, embeddings)

# %%
file_path = "vector_index.pkl"
with open(file_path, "wb") as f:
    pickle.dump(vectorindex_vertex, f)

# %%
if os.path.exists(file_path):
    with open(file_path, "rb") as f:
        vectorIndex = pickle.load(f)

# %%
# Function to query Gemini model via Vertex AI using API key
def query_gemini_model(question):
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "instances": [{"question": question}],
        "parameters": {"temperature": 0.9, "maxOutputTokens": 500}
    }

    response = requests.post(endpoint, headers=headers, json=payload)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return None

# %%
from langchain.llms import BaseLLM
import requests

# %%
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.llms import BaseLLM

# Custom LLM wrapper for Gemini API using BaseLLM
class GeminiLLM(BaseLLM):
    def _generate(self, prompt: str, stop: list = None) -> str:
        # Call the Gemini API and return the generated answer
        return query_gemini_model(prompt)

    def _llm_type(self) -> str:
        return "gemini"

# Instantiate the custom LLM
gemini_llm = GeminiLLM()

# %%
# Assuming vectorIndex is already defined (from previous steps)
# Use the custom LLM in the LLMChain
chain = RetrievalQAWithSourcesChain.from_llm(llm=gemini_llm, retriever=vectorIndex.as_retriever())

# %%
# Ask a question
query = "what is the price of Tiago iCNG?"
langchain.debug = True
answer = chain({"question": query}, return_only_outputs=True)

# Debugging the answer
if answer:
    print("Answer:", answer)
else:
    print("Error: No valid answer received.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 # Ask a question
#       2 query = "what is the price of Tiago iCNG?"
# ----> 3 langchain.debug = True
#       4 answer = chain({"question": query}, return_only_outputs=True)
#       6 # Debugging the answer
#
# NameError: name 'langchain' is not defined

# %%
# Ask a question
query = "what is the price of Tiago iCNG?"
answer = chain({"question": query}, return_only_outputs=True)

# Debugging the answer
if answer:
    print("Answer:", answer)
else:
    print("Error: No valid answer received.")
# Out:
# Error: 401, {
#   "error": {
#     "code": 401,
#     "message": "Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.",
#     "status": "UNAUTHENTICATED",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "ACCESS_TOKEN_TYPE_UNSUPPORTED",
#         "metadata": {
#           "service": "aiplatform.googleapis.com",
#           "method": "google.cloud.aiplatform.v1.PredictionService.Predict"
#         }
#       }
#     ]
#   }
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 3
#       1 # Ask a question
#       2 query = "what is the price of Tiago iCNG?"
# ----> 3 answer = chain({"question": query}, return_only_outputs=True)
#       5 # Debugging the answer
#       6 if answer:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\qa_with_sources\base.py:166, in BaseQAWithSourcesChain._call(self, inputs, run_manager)
#     163 else:
#     164     docs = self._get_docs(inputs)  # type: ignore[call-arg]
# --> 166 answer = self.combine_documents_chain.run(
#     167     input_documents=docs, callbacks=_run_manager.get_child(), **inputs
#     168 )
#     169 answer, sources = self._split_sources(answer)
#     170 result: Dict[str, Any] = {
#     171     self.answer_key: answer,
#     172     self.sources_answer_key: sources,
#     173 }
#
# File ~\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:611, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607         _output_key
#     608     ]
#     610 if kwargs and not args:
# --> 611     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612         _output_key
#     613     ]
#     615 if not kwargs and not args:
#     616     raise ValueError(
#     617         "`run` supported with either positional arguments or keyword arguments,"
#     618         " but none were provided."
#     619     )
#
# File ~\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\combine_documents\base.py:138, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     136 # Other keys are assumed to be needed for LLM prediction
#     137 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 138 output, extra_return_dict = self.combine_docs(
#     139     docs, callbacks=_run_manager.get_child(), **other_keys
#     140 )
#     141 extra_return_dict[self.output_key] = output
#     142 return extra_return_dict
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\combine_documents\map_reduce.py:240, in MapReduceDocumentsChain.combine_docs(self, docs, token_max, callbacks, **kwargs)
#     228 def combine_docs(
#     229     self,
#     230     docs: List[Document],
#    (...)
#     233     **kwargs: Any,
#     234 ) -> Tuple[str, dict]:
#     235     """Combine documents in a map reduce manner.
#     236
#     237     Combine by mapping first chain over all documents, then reducing the results.
#     238     This reducing can be done recursively if needed (if there are many documents).
#     239     """
# --> 240     map_results = self.llm_chain.apply(
#     241         # FYI - this is parallelized and so it is fast.
#     242         [{self.document_variable_name: d.page_content, **kwargs} for d in docs],
#     243         callbacks=callbacks,
#     244     )
#     245     question_result_key = self.llm_chain.output_key
#     246     result_docs = [
#     247         Document(page_content=r[question_result_key], metadata=docs[i].metadata)
#     248         # This uses metadata from the docs, and the textual results from `results`
#     249         for i, r in enumerate(map_results)
#     250     ]
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\llm.py:251, in LLMChain.apply(self, input_list, callbacks)
#     249 except BaseException as e:
#     250     run_manager.on_chain_error(e)
# --> 251     raise e
#     252 outputs = self.create_outputs(response)
#     253 run_manager.on_chain_end({"outputs": outputs})
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\llm.py:248, in LLMChain.apply(self, input_list, callbacks)
#     242 run_manager = callback_manager.on_chain_start(
#     243     None,
#     244     {"input_list": input_list},
#     245     name=self.get_name(),
#     246 )
#     247 try:
# --> 248     response = self.generate(input_list, run_manager=run_manager)
#     249 except BaseException as e:
#     250     run_manager.on_chain_error(e)
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:755, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     747 def generate_prompt(
#     748     self,
#     749     prompts: list[PromptValue],
#    (...)
#     752     **kwargs: Any,
#     753 ) -> LLMResult:
#     754     prompt_strings = [p.to_string() for p in prompts]
# --> 755     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:950, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     935 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     936     run_managers = [
#     937         callback_manager.on_llm_start(
#     938             self._serialized,
#    (...)
#     948         )
#     949     ]
# --> 950     output = self._generate_helper(
#     951         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     952     )
#     953     return output
#     954 if len(missing_prompts) > 0:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:793, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     791         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
#     792     raise e
# --> 793 flattened_outputs = output.flatten()
#     794 for manager, flattened_output in zip(run_managers, flattened_outputs):
#     795     manager.on_llm_end(flattened_output)
#
# AttributeError: 'NoneType' object has no attribute 'flatten'
